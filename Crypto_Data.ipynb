# %%
#import dependencies
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# Read crypto_data.csv into Pandas. The dataset was obtained from CryptoCompare.
#read CSV file
d1 = ('crypto_data.csv')
crypto_df = pd.read_csv(d1)
crypto_df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %%
# Discard all cryptocurrencies that are not being traded. In other words, filter for currencies that are currently being traded. Once you have done this, drop the IsTrading column from the dataframe.
# drop the cryptocurrencies that are not traded
df1 = crypto_df[crypto_df['IsTrading']!= False]
df1
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 1           365      365Coin          X11       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 3           611    SixEleven      SHA-256       True       PoW
# 4           808          808      SHA-256       True   PoW/PoS
# ...         ...          ...          ...        ...       ...
# 1243       SERO   Super Zero       Ethash       True       PoW
# 1244        UOS          UOS      SHA-256       True      DPoI
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
#Print the frequency for the IsTrading variable
df1['IsTrading'].value_counts()
# Out:
# True    1144
# Name: IsTrading, dtype: int64

# %%
#Remove all rows that have at least one null value.
# Rename and drop missing rows
#rename first column
df2=df1.rename(columns={'Unnamed: 0': 'Symbol'})
df2.dropna(inplace=True)
df2
# Out:
#      Symbol     CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0        42      42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 2       404      404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 4       808          808      SHA-256       True   PoW/PoS     0.000000e+00
# 5      1337    EliteCoin          X13       True   PoW/PoS     2.927942e+10
# 7       BTC      Bitcoin      SHA-256       True       PoW     1.792718e+07
# ...     ...          ...          ...        ...       ...              ...
# 1238   ZEPH       ZEPHYR      SHA-256       True      DPoS     2.000000e+09
# 1242    GAP      Gapcoin       Scrypt       True   PoW/PoS     1.493105e+07
# 1245    BDX       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246    ZEN      Horizen     Equihash       True       PoW     7.296538e+06
# 1247    XBC  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# ...

# %%
# Filter for cryptocurrencies that have been mined. That is, the total coins mined should be greater than zero.
#remove coins that have not been mined
df3 = df2[df2['TotalCoinsMined']>0]
df3.head(20)
# Out:
#    Symbol          CoinName       Algorithm  IsTrading ProofType  \
# 0      42           42 Coin          Scrypt       True   PoW/PoS
# 2     404           404Coin          Scrypt       True   PoW/PoS
# 5    1337         EliteCoin             X13       True   PoW/PoS
# 7     BTC           Bitcoin         SHA-256       True       PoW
# 8     ETH          Ethereum          Ethash       True       PoW
# 9     LTC          Litecoin          Scrypt       True       PoW
# 10   DASH              Dash             X11       True   PoW/PoS
# 11    XMR            Monero  CryptoNight-V7       True       PoW
# 12    ETC  Ethereum Classic          Ethash       True       PoW
# 13    ZEC             ZCash        Equihash       True       PoW
# 14    BTS         Bitshares         SHA-512       True       PoS
# 15    DGB          DigiByte        Multiple       True       PoW
# 16   BTCD       BitcoinDark         SHA-256       True   PoW/PoS
# ...

# %%
# In order for your dataset to be comprehensible to a machine learning algorithm, its data should be numeric. Since the coin names do not contribute to the analysis of the data, delete the CoinName from the original dataframe.
#Drop unused columns
df4 = df3.drop(['CoinName', 'IsTrading'], axis=1)
#set index as the symbol
df4.set_index('Symbol', inplace=True)
df4.head()
# Out:
#        Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# Symbol
# 42        Scrypt   PoW/PoS     4.199995e+01              42
# 404       Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337         X13   PoW/PoS     2.927942e+10    314159265359
# BTC      SHA-256       PoW     1.792718e+07        21000000
# ETH       Ethash       PoW     1.076842e+08               0

# %%
# Your next step in data preparation is to convert the remaining features with text values, Algorithm and ProofType, into numerical data. To accomplish this task, use Pandas to create dummy variables. Examine the number of rows and columns of your dataset now. How did they change?
#create dummies for categorical variables
dummies = pd.get_dummies(df4, columns = ['Algorithm', 'ProofType'])
dummies
# Out:
#         TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# Symbol
# 42         4.199995e+01              42                                 0
# 404        1.055185e+09       532000000                                 0
# 1337       2.927942e+10    314159265359                                 0
# BTC        1.792718e+07        21000000                                 0
# ETH        1.076842e+08               0                                 0
# ...                 ...             ...                               ...
# ZEPH       2.000000e+09      2000000000                                 0
# GAP        1.493105e+07       250000000                                 0
# BDX        9.802226e+08      1400222610                                 0
# ZEN        7.296538e+06        21000000                                 0
# XBC        1.283270e+05         1000000                                 0
#
# ...

# %%
# Standardize your dataset so that columns that contain larger values do not unduly influence the outcome.
scaled = StandardScaler().fit_transform(dummies)
scaled
# Out:
# array([[-0.11710817, -0.1528703 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.145009  , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [ 0.52494561,  4.48942416, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        ...,
#        [-0.09561336, -0.13217937, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11694817, -0.15255998, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11710536, -0.15285552, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ]])

# %%
# Dimension Reduction

#Initialize PCA Model
pca = PCA(n_components=0.90)

#fit the model
crypto_pca = pca.fit_transform(scaled)

#create a pandas dataframe of the principal components
pca_df = pd.DataFrame(crypto_pca)
pca_df
# Out:
#            0         1         2         3             4             5   \
# 0   -0.335099  1.032189 -0.590713  0.001397  2.734816e-12 -5.417255e-15
# 1   -0.318434  1.032331 -0.591126  0.001386  2.712386e-12 -5.575109e-15
# 2    2.305468  1.656383 -0.683617  0.004731  9.322259e-12 -6.700325e-15
# 3   -0.145184 -1.320593  0.192813 -0.001229 -2.420624e-12  2.357806e-15
# 4   -0.151768 -2.036192  0.396182 -0.001705 -3.352037e-12  2.706411e-15
# ..        ...       ...       ...       ...           ...           ...
# 527  2.471251  0.822241 -0.071160 -0.008206 -1.632875e-11 -2.711489e-16
# 528 -0.333144  1.032071 -0.590740  0.001399  2.739500e-12 -5.504781e-15
# 529  0.324349 -2.312308  0.421515 -0.001319 -2.587411e-12  3.997274e-15
# 530 -0.149364 -2.049336  0.412968 -0.001745 -3.429876e-12  4.424198e-15
# 531 -0.289957  0.821195 -0.276327  0.000555  1.083100e-12 -2.978278e-15
#
#                6         7         8         9   ...            64  \
# ...

# %%
# Fetch the explained variance
pca.explained_variance_ratio_
# Out:
# array([0.0279317 , 0.02141802, 0.02051615, 0.02044661, 0.0204466 ,
#        0.0204466 , 0.0204466 , 0.02042554, 0.01870913, 0.01756291,
#        0.01741106, 0.01629007, 0.01596154, 0.01551138, 0.01435005,
#        0.01321122, 0.01236583, 0.01206255, 0.01104295, 0.01071499,
#        0.01049079, 0.01040887, 0.01039089, 0.01037741, 0.01035414,
#        0.01034034, 0.01029605, 0.01028233, 0.01028139, 0.01028139,
#        0.01028138, 0.01027965, 0.01027051, 0.01026331, 0.01026202,
#        0.01025761, 0.01025565, 0.01025068, 0.01024924, 0.01024279,
#        0.01024259, 0.01024259, 0.0102419 , 0.01024018, 0.01023676,
#        0.01023495, 0.01023   , 0.01022442, 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
# ...

# %%
#further reduce the dataset dimensions with t-SNE
from sklearn.manifold import TSNE
tsne = TSNE(learning_rate=200)

tsne_features = tsne.fit_transform(pca_df)

# %%
#Determine the number of TSNE Features
tsne_features.shape
# Out:
# (532, 2)

# %%
#Create a scatter plot by principal component

plt.scatter(tsne_features[:,0], tsne_features[:,1])
plt.show()

# %%
# Cluster Analysis with k-Means
# Initializing model with K = 1-10
from sklearn.cluster import KMeans
inertia = []
k = list(range(1, 11))

#for loop to identify the best k
for i in k:
    km = KMeans(n_clusters=i, random_state=42)
    km.fit(pca_df)
    inertia.append(km.inertia_)


# Define a DataFrame to plot the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# C:\Users\Other\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
